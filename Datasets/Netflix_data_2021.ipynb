# %%
import pandas as pd
import opendatasets as od
import os 
import csv 
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

# %%
dataset=('https://www.kaggle.com/datasets/satpreetmakhija/netflix-movies-and-tv-shows-2021')

# %%
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\netflix-movies-and-tv-shows-2021" (use force=True to force download)

# %%
data_dir=('.\netflix-movies-and-tv-shows-2021')

# %%
#load data
netflix_data21 = "netflix-movies-and-tv-shows-2021/netflixData.csv"

# %%
current_netflix_data = pd.read_csv(netflix_data21)

# %%
print(len(current_netflix_data))
# comparable with pie chart from cleaned data
# this one will be used to show what we have before data is cleaned
# will show that we are using a sample of the population
content_type = current_netflix_data["Content Type"].value_counts()
content_type
content_type.plot.pie(title= 'Content Type', figsize = (8,8), explode = (0.05, 0.05), autopct='%1.1f%%',colors=['red','blue'], startangle=30 )
plt.savefig("Content Type _Pie uncleaned data_2021.png") 
plt.legend();
# Out:
# 5967

# %%
# Cleaning the data
# Remove columns first and then NA rows
reduced_df = current_netflix_data.drop(['Cast', 'Director', 'Description'], axis = 1)
reduced_df

reduced_df.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Genres                   0
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
nf_df = reduced_df.dropna(subset=['Date Added', 'Imdb Score', 'Production Country'])

# nf_df.head(100)
# nf_df.isnull().sum()

content_type = nf_df["Content Type"].value_counts()
content_type
content_type.plot.pie(title= 'Content Type', figsize = (8,8), explode = (0.05, 0.05), autopct='%1.1f%%',colors=['red','blue'], startangle=30 )
plt.savefig("Content Type _Pie cleaned data_2021.png") 
plt.legend()

# %%
# # new_nf_df = current_netflix_data.drop(["Director"], axis=1)
# new_nf_df = current_netflix_data.copy()
# # droped na values (rows with null values in these categories)
# nf_df = new_nf_df.dropna(subset=['Director', 'Date Added', 'Cast', 'Imdb Score', 'Production Country'])
# nf_df.head(100)

# %%
# nf_df.columns

# %%
# print(len(nf_df))

# %%
nf_df.isnull().sum()
# Out:
# Show Id               0
# Title                 0
# Genres                0
# Production Country    0
# Release Date          0
# Rating                0
# Duration              0
# Imdb Score            0
# Content Type          0
# Date Added            0
# dtype: int64

# %%
# current_netflix_data["Release Date"].unique

# %%
# #dropping columns
# new_reduced_df = nf_df.drop(['Cast', 'Director', 'Description'], axis = 1)
# new_reduced = new_reduced_df.reset_index(drop=True)
# new_reduced

# %%
# convert all of 'new_reduced' t0 'final_nf_df'
final_nf_df = nf_df.loc[nf_df["Content Type"]!= "TV Show"]
final_nf_df
# Out:
#                                    Show Id  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b
# 6     0555e67e-f624-4a05-93e4-55c117d0056d
# ...                                    ...
# 5957  309b0d7e-357b-45ce-b1cf-617b4c3593d5
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5
# 5961  06aab7f2-9756-4680-98cf-209b7ca86a9b
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26
#
#                                         Title  \
# 1                                      #Alive
# 2               #AnneFrank - Parallel Stories
# 4                            #cats_the_mewvie
# 5                           #FriendButMarried
# 6                         #FriendButMarried 2
# ...                                       ...
# 5957                                Zoot Suit
# 5958                                     Zozo
# 5961  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 5962                                الف مبروك
# 5965                                  반드시 잡는다
#
#                                               Genres  \
# 1     Horror Movies, International Movies, Thrillers
# 2                Documentaries, International Movies
# 4                Documentaries, International Movies
# 5      Dramas, International Movies, Romantic Movies
# 6      Dramas, International Movies, Romantic Movies
# ...                                              ...
# 5957           Cult Movies, Dramas, Music & Musicals
# 5958                    Dramas, International Movies
# 5961                 Documentaries, Music & Musicals
# 5962          Comedies, Dramas, International Movies
# 5965         Dramas, International Movies, Thrillers
#
#                                      Production Country  Release Date Rating  \
# 1                                           South Korea        2020.0  TV-MA
# 2                                                 Italy        2019.0  TV-14
# 4                                                Canada        2020.0  TV-14
# 5                                             Indonesia        2018.0   TV-G
# 6                                             Indonesia        2020.0   TV-G
# ...                                                 ...           ...    ...
# 5957                                      United States        1981.0      R
# 5958  Sweden, Czech Republic, United Kingdom, Denmar...        2005.0  TV-MA
# 5961              United Kingdom, Canada, United States        2019.0  TV-MA
# 5962                                              Egypt        2009.0  TV-14
# 5965                                        South Korea        2017.0  TV-MA
#
#      Duration Imdb Score Content Type         Date Added
# 1      99 min     6.2/10        Movie  September 8, 2020
# 2      95 min     6.4/10        Movie       July 1, 2020
# 4      90 min     5.1/10        Movie   February 5, 2020
# 5     102 min     7.0/10        Movie       May 21, 2020
# 6     104 min     7.0/10        Movie      June 28, 2020
# ...       ...        ...          ...                ...
# 5957  103 min     7.0/10        Movie     April 15, 2021
# 5958   99 min     6.7/10        Movie   October 19, 2020
# 5961   90 min     7.4/10        Movie      March 1, 2020
# 5962  115 min     7.4/10        Movie     April 25, 2020
# 5965  110 min     6.5/10        Movie  February 28, 2018
#
# [3497 rows x 10 columns]

# %%
#totals
#content = new_reduced.groupby(["Content Type"]).count()
content = final_nf_df["Content Type"].value_counts()
content
year = final_nf_df["Release Date"].value_counts()
year
#Find/remove outlier rating (NC-17) 
rating = final_nf_df.loc[final_nf_df["Rating"] != "NC-17"]
rating = rating["Rating"].value_counts()
rating
# Out:
# TV-MA    1426
# TV-14     890
# R         375
# TV-PG     284
# PG-13     224
# PG        120
# TV-G       68
# TV-Y       52
# TV-Y7      42
# G          15
# Name: Rating, dtype: int64

# %%
rating.plot(kind = "barh", alpha = .50, figsize =(20,5), color = "red")
plt.xlabel("Number of Titles")
plt.ylabel("Type of Ratings")
plt.title("Number of Titles by Rating")
plt.savefig("Number of Titles by Rating_2021.png")
plt.show()

# %%
#from datetime import datetime
import datetime
import time
final_nf_df['Date Added'] = pd.to_datetime(final_nf_df['Date Added'])
final_nf_df['Date Added'] =final_nf_df['Date Added'].dt.strftime('%Y')
final_nf_df
# Out:
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#                                    Show Id  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b
# 6     0555e67e-f624-4a05-93e4-55c117d0056d
# ...                                    ...
# 5957  309b0d7e-357b-45ce-b1cf-617b4c3593d5
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5
# 5961  06aab7f2-9756-4680-98cf-209b7ca86a9b
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26
#
#                                         Title  \
# 1                                      #Alive
# 2               #AnneFrank - Parallel Stories
# 4                            #cats_the_mewvie
# 5                           #FriendButMarried
# 6                         #FriendButMarried 2
# ...                                       ...
# 5957                                Zoot Suit
# 5958                                     Zozo
# 5961  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 5962                                الف مبروك
# 5965                                  반드시 잡는다
#
#                                               Genres  \
# 1     Horror Movies, International Movies, Thrillers
# 2                Documentaries, International Movies
# 4                Documentaries, International Movies
# 5      Dramas, International Movies, Romantic Movies
# 6      Dramas, International Movies, Romantic Movies
# ...                                              ...
# 5957           Cult Movies, Dramas, Music & Musicals
# 5958                    Dramas, International Movies
# 5961                 Documentaries, Music & Musicals
# 5962          Comedies, Dramas, International Movies
# 5965         Dramas, International Movies, Thrillers
#
#                                      Production Country  Release Date Rating  \
# 1                                           South Korea        2020.0  TV-MA
# 2                                                 Italy        2019.0  TV-14
# 4                                                Canada        2020.0  TV-14
# 5                                             Indonesia        2018.0   TV-G
# 6                                             Indonesia        2020.0   TV-G
# ...                                                 ...           ...    ...
# 5957                                      United States        1981.0      R
# 5958  Sweden, Czech Republic, United Kingdom, Denmar...        2005.0  TV-MA
# 5961              United Kingdom, Canada, United States        2019.0  TV-MA
# 5962                                              Egypt        2009.0  TV-14
# 5965                                        South Korea        2017.0  TV-MA
#
#      Duration Imdb Score Content Type Date Added
# 1      99 min     6.2/10        Movie       2020
# 2      95 min     6.4/10        Movie       2020
# 4      90 min     5.1/10        Movie       2020
# 5     102 min     7.0/10        Movie       2020
# 6     104 min     7.0/10        Movie       2020
# ...       ...        ...          ...        ...
# 5957  103 min     7.0/10        Movie       2021
# 5958   99 min     6.7/10        Movie       2020
# 5961   90 min     7.4/10        Movie       2020
# 5962  115 min     7.4/10        Movie       2020
# 5965  110 min     6.5/10        Movie       2018
#
# [3497 rows x 10 columns]

# %%
final_nf_df[['IMDB Score', 'delete']] = final_nf_df['Imdb Score'].str.split('/', expand=True)
#new_reduced.dtypes
# Out:
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
final_nf_df[['Duration (min)', 'deletemin']] = final_nf_df['Duration'].str.split(' ', expand=True)
final_nf_df["Release Date"]=final_nf_df["Release Date"].astype("int")
final_nf_df["IMDB Score"]=final_nf_df["IMDB Score"].astype("float")
final_nf_df["Duration (min)"]=final_nf_df["Duration (min)"].astype("int")
final_nf_df
# Out:
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                    Show Id  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b
# 6     0555e67e-f624-4a05-93e4-55c117d0056d
# ...                                    ...
# 5957  309b0d7e-357b-45ce-b1cf-617b4c3593d5
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5
# 5961  06aab7f2-9756-4680-98cf-209b7ca86a9b
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26
#
#                                         Title  \
# 1                                      #Alive
# 2               #AnneFrank - Parallel Stories
# 4                            #cats_the_mewvie
# 5                           #FriendButMarried
# 6                         #FriendButMarried 2
# ...                                       ...
# 5957                                Zoot Suit
# 5958                                     Zozo
# 5961  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 5962                                الف مبروك
# 5965                                  반드시 잡는다
#
#                                               Genres  \
# 1     Horror Movies, International Movies, Thrillers
# 2                Documentaries, International Movies
# 4                Documentaries, International Movies
# 5      Dramas, International Movies, Romantic Movies
# 6      Dramas, International Movies, Romantic Movies
# ...                                              ...
# 5957           Cult Movies, Dramas, Music & Musicals
# 5958                    Dramas, International Movies
# 5961                 Documentaries, Music & Musicals
# 5962          Comedies, Dramas, International Movies
# 5965         Dramas, International Movies, Thrillers
#
#                                      Production Country  Release Date Rating  \
# 1                                           South Korea          2020  TV-MA
# 2                                                 Italy          2019  TV-14
# 4                                                Canada          2020  TV-14
# 5                                             Indonesia          2018   TV-G
# 6                                             Indonesia          2020   TV-G
# ...                                                 ...           ...    ...
# 5957                                      United States          1981      R
# 5958  Sweden, Czech Republic, United Kingdom, Denmar...          2005  TV-MA
# 5961              United Kingdom, Canada, United States          2019  TV-MA
# 5962                                              Egypt          2009  TV-14
# 5965                                        South Korea          2017  TV-MA
#
#      Duration Imdb Score Content Type Date Added  IMDB Score delete  \
# 1      99 min     6.2/10        Movie       2020         6.2     10
# 2      95 min     6.4/10        Movie       2020         6.4     10
# 4      90 min     5.1/10        Movie       2020         5.1     10
# 5     102 min     7.0/10        Movie       2020         7.0     10
# 6     104 min     7.0/10        Movie       2020         7.0     10
# ...       ...        ...          ...        ...         ...    ...
# 5957  103 min     7.0/10        Movie       2021         7.0     10
# 5958   99 min     6.7/10        Movie       2020         6.7     10
# 5961   90 min     7.4/10        Movie       2020         7.4     10
# 5962  115 min     7.4/10        Movie       2020         7.4     10
# 5965  110 min     6.5/10        Movie       2018         6.5     10
#
#       Duration (min) deletemin
# 1                 99       min
# 2                 95       min
# 4                 90       min
# 5                102       min
# 6                104       min
# ...              ...       ...
# 5957             103       min
# 5958              99       min
# 5961              90       min
# 5962             115       min
# 5965             110       min
#
# [3497 rows x 14 columns]

# %%
final_nf_2021 = final_nf_df.drop(['delete', 'deletemin', 'Imdb Score', 'Duration','Show Id'], axis = 1)
final_nf_2021
# Out:
#                                         Title  \
# 1                                      #Alive
# 2               #AnneFrank - Parallel Stories
# 4                            #cats_the_mewvie
# 5                           #FriendButMarried
# 6                         #FriendButMarried 2
# ...                                       ...
# 5957                                Zoot Suit
# 5958                                     Zozo
# 5961  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 5962                                الف مبروك
# 5965                                  반드시 잡는다
#
#                                               Genres  \
# 1     Horror Movies, International Movies, Thrillers
# 2                Documentaries, International Movies
# 4                Documentaries, International Movies
# 5      Dramas, International Movies, Romantic Movies
# 6      Dramas, International Movies, Romantic Movies
# ...                                              ...
# 5957           Cult Movies, Dramas, Music & Musicals
# 5958                    Dramas, International Movies
# 5961                 Documentaries, Music & Musicals
# 5962          Comedies, Dramas, International Movies
# 5965         Dramas, International Movies, Thrillers
#
#                                      Production Country  Release Date Rating  \
# 1                                           South Korea          2020  TV-MA
# 2                                                 Italy          2019  TV-14
# 4                                                Canada          2020  TV-14
# 5                                             Indonesia          2018   TV-G
# 6                                             Indonesia          2020   TV-G
# ...                                                 ...           ...    ...
# 5957                                      United States          1981      R
# 5958  Sweden, Czech Republic, United Kingdom, Denmar...          2005  TV-MA
# 5961              United Kingdom, Canada, United States          2019  TV-MA
# 5962                                              Egypt          2009  TV-14
# 5965                                        South Korea          2017  TV-MA
#
#      Content Type Date Added  IMDB Score  Duration (min)
# 1           Movie       2020         6.2              99
# 2           Movie       2020         6.4              95
# 4           Movie       2020         5.1              90
# 5           Movie       2020         7.0             102
# 6           Movie       2020         7.0             104
# ...           ...        ...         ...             ...
# 5957        Movie       2021         7.0             103
# 5958        Movie       2020         6.7              99
# 5961        Movie       2020         7.4              90
# 5962        Movie       2020         7.4             115
# 5965        Movie       2018         6.5             110
#
# [3497 rows x 9 columns]

# %%
# content = final_nf_2021["Content Type"].value_counts()
# content
# content.plot.pie(y= 'Content Type', figsize = (8,8), autopct='%1.1f%%',colors=['red','blue'], startangle=30 )
# plt.savefig("Content Type _Pie.png") 
# plt.legend();

# %%
year = final_nf_2021["Release Date"].value_counts()
year
year_counts = final_nf_2021.groupby("Release Date").count()

pandas_line = year_counts[["Title"]].rename(columns = {"Title":"Total Number of Movies"})
pandas_line.plot(kind = "line", color = "red")
plt.ylabel("Total Number of Movies")
plt.title("Total Movies vs Release Date")
plt.savefig("Total Movies vs Release Date_2021.png")
plt.show()
# Regression line

# %%
# rating = rating["Rating"].value_counts()
rating.plot.pie(shadow = True, figsize = (8,8), autopct='%1.1f%%')
plt.title("Movie Ratings")
plt.savefig('Ratings_pie_2021.png')
plt.legend()

# %%
#pokemon_games = df.loc[df['Name'].str.contains("pokemon", case=False)]
final_Production_countries = final_nf_2021.loc[final_nf_2021["Genres"].str.contains(",")== False]
final_Production_countries
countries_count = final_Production_countries.groupby("Genres").count()
group_data= final_Production_countries.groupby("Genres")
countries_count_df = pd.DataFrame({"Total Genres":group_data['Genres'].count()})
countries_count_df_sort = countries_count_df.sort_values(by=['Total Genres'], ascending=True)
countries_count_df_sort
pandas_bar = countries_count_df_sort[["Total Genres"]].rename(columns = {"Title":"Total Number of Movies"})
pandas_bar = countries_count_df_sort[["Total Genres"]]
pandas_bar.plot(kind = "barh", alpha = .50, figsize =(20,5), color = "red")
plt.xlabel("Number of Titles")
plt.ylabel("Genre")
plt.title("Number of Titles by Genre")
plt.savefig("Numbers of Titles by Genres_2021.png")
plt.show()

# %%
#pokemon_games = df.loc[df['Name'].str.contains("pokemon", case=False)]
final_Production_countries = final_nf_2021.loc[final_nf_2021["Production Country"].str.contains(",")== False]
final_Production_countries
countries_count = final_Production_countries.groupby("Production Country").count()
group_data= final_Production_countries.groupby("Production Country")
countries_count_df = pd.DataFrame({"Total Movies":group_data['Production Country'].count()})
countries_count_df_sort = countries_count_df.sort_values(by=['Total Movies'], ascending=True)
countries_count_df_sort
top_countries_count_df_sort = countries_count_df_sort.loc[countries_count_df_sort["Total Movies"] > 20]
pandas_bar = top_countries_count_df_sort[["Total Movies"]].rename(columns = {"Title":"Total Number of Movies"})
pandas_bar = top_countries_count_df_sort[["Total Movies"]]
pandas_bar.plot(kind = "barh", alpha = .50, figsize=(13,7), color = "red", )
# plt.xticks(rotation=45,
#     horizontalalignment='right')
plt.ylabel("Country")
plt.xlabel("Total Number of Movies")
plt.title("Top 20 Movie Producing Countries")
plt.savefig("Total Movie Production by Country horizontal_2021.png")
plt.show()

# %%
countries_count_df_sort
top_countries_count_df_sort
# Out:
#                     Total Movies
# Production Country
# Argentina                     24
# Italy                         24
# South Korea                   28
# Thailand                      33
# Germany                       37
# Brazil                        39
# Hong Kong                     45
# Egypt                         52
# Mexico                        52
# Indonesia                     52
# France                        52
# Turkey                        56
# Canada                        58
# Nigeria                       58
# Japan                         67
# Philippines                   68
# Spain                         86
# United Kingdom               103
# India                        583
# United States               1156

# %%
x_values = final_nf_2021["Release Date"]
y_values = final_nf_2021["IMDB Score"]
plt.figure(figsize=(20, 5))
plt.scatter(x_values, y_values, alpha=0.5)
#plt.yticks(np.arange(min(0), max(10)+1, 1.0))

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
#print(regress_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.xlabel("Year (Movie's release date)")
plt.ylabel('Imdb Score')
plt.title('Imdb Score per Year')

# Label plot and annotate the line equation
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(1960,3),fontsize=15,color="black")
# Print r value
print(f"The r-value is: {rvalue**2}")

plt.savefig("Rating per year2021.png")
plt.show()
# Out:
# y = -0.02x +44.86
# The r-value is: 0.018993423258591505

# %%
x = final_nf_2021["Duration (min)"]
y = final_nf_2021["IMDB Score"]
plt.figure(figsize=(20, 5))
plt.scatter(x, y, alpha=0.5, color="red")
#plt.yticks(np.arange(min(0), max(10)+1, 1.0))
plt.xlabel('Duration of movie')
plt.ylabel('Imdb Score')
plt.title('Imbd Score and Run time')
plt.savefig("Rating vs Time_2021.png")
plt.show()

# %%
# year_max = final_nf_2021.groupby("Release Date").max()
# year_max

# %%
# movie_ratings = ["TV-MA", "TV-14", "R", "TV-PG", "PG-13", "PG", "TV-G", "TV-Y", "TV-Y7", "G"]

# Imdb_rating_data = []

# # Calculate the IQR and quantitatively determine if there are any potential outliers. 
    
# for movie_rating in movie_ratings:
#     final_rating_data = final_nf_2021.loc[final_nf_2021["Rating"] == movie_rating, "IMDB Score"]
#     # add subset 
#     Imdb_rating_data.append(final_rating_data)

#     # Determine outliers using upper and lower bounds
#     quartiles = final_rating_data.quantile([.25, .5, .75])
#     lowerq = quartiles[0.25]
#     upperq = quartiles[0.75]
#     iqr = upperq - lowerq
#     lower_bound = lowerq - (1.5*iqr)
#     upper_bound = upperq + (1.5*iqr)
#     outliers = final_rating_data.loc[(final_rating_data < lower_bound) | (final_rating_data > upper_bound)]
#     print(f"{movie_rating}'s potential outliers: {outliers}")
# print(Imdb_rating_data)

# %%
# plt.boxplot(Imdb_rating_data, labels=movie_ratings)
# plt.ylabel("Movie Ratings")
# plt.show()
