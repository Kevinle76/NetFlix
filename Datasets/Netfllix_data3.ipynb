# %%
import pandas as pd
import opendatasets as od

# %%
dataset=('https://www.kaggle.com/datasets/satpreetmakhija/netflix-movies-and-tv-shows-2021')

# %%
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\netflix-movies-and-tv-shows-2021" (use force=True to force download)

# %%
data_dir=('.\netflix-movies-and-tv-shows-2021')

# %%
data_df = pd.read_csv('C:/Users/stefa/OneDrive/Desktop/Projects/Datasets/netflix-movies-and-tv-shows-2021/netflixData.csv')

# %%
data_df
# Out:
#                                    Show Id                          Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# ...                                    ...                            ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                   دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                           海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
data_df.columns
# Out:
# Index(['Show Id', 'Title', 'Description', 'Director', 'Genres', 'Cast',
#        'Production Country', 'Release Date', 'Rating', 'Duration',
#        'Imdb Score', 'Content Type', 'Date Added'],
#       dtype='object')

# %%
print(len(data_df))
# Out:
# 5967

# %%
data_df.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %% [markdown]
# """
# <br>How current are the release dates of these titles?
# <br>Do movies or tv shows have a higher average vote?
# <br>How many countries have productions on Netflix?
# <br>Which countries have the highest rated productions?
# <br>What are all the current genres offered?
# <br>How many productions in each genre category per country?
# <br>How many comedies are TV shows and how many are movies?
# <br>Which country is releasing the most current comedies?
# <br>What are comedies generally rated across these productions?
# <br>How many comedies have been produced from each country? And are these movies or tv shows? How long (duration) are they?
# """
