# %%
import opendatasets as od

# %%
dataset = "https://www.kaggle.com/datasets/vainero/public-schools"

# %%
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\public-schools" (use force=True to force download)

# %%
data_dir = ('.\public-schools')

# %%
import pandas as pd

# %%
data_df = pd.read_csv('C:/Users/stefa/OneDrive/Desktop/Projects/Datasets/public-schools/Public_Schools.csv')
# Out:
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_df
# Out:
#                 X          Y     FID        NCESID  \
# 0      -88.028074  32.791868       1   10168000578
# 1      -87.918717  32.846392       2   10168000864
# 2      -87.893147  32.838000       3   10168001452
# 3      -87.877214  32.833911       4   10168001520
# 4      -87.620561  32.998976       5   10171000588
# ...           ...        ...     ...           ...
# 103476 -84.243449  39.827366  101996  390146605660
# 103477 -85.972382  31.806538  101997   10279002155
# 103478 -88.063774  43.059532  101998  551599002884
# 103479 -85.496394  33.313354  101999   10282002171
# 103480 -85.032184  32.359190  102000   10288002192
#
#                                NAME                ADDRESS       ADDRESS2  \
# 0             PARAMOUNT JR HIGH SCH                 HWY 20  NOT AVAILABLE
# 1        PETER J KIRKSEY CAREER CTR      836 COUNTY RD 131  NOT AVAILABLE
# 2                 EUTAW PRIMARY SCH    212 EUTAW AVE SOUTH  NOT AVAILABLE
# ...

# %%
data_df.columns
# Out:
# Index(['X', 'Y', 'FID', 'NCESID', 'NAME', 'ADDRESS', 'ADDRESS2', 'CITY',
#        'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION',
#        'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE',
#        'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCE_DAT', 'VAL_METHOD',
#        'VAL_DATE', 'WEBSITE', 'LEVEL_', 'ENROLLMENT', 'START_GRAD',
#        'END_GRADE', 'DISTRICT_I', 'FULL_TIME_', 'SHELTER_ID'],
#       dtype='object')
