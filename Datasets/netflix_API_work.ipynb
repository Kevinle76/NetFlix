# %%
import requests 
from pprint import pprint

# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/search/titles"

querystring = {"order_by":"date","type":"movie"}

headers = {
	"X-RapidAPI-Host": "unogs-unogs-v1.p.rapidapi.com",
	"X-RapidAPI-Key": "95b5cc42f9msh0acb75461fff8eap15381ajsnfed6d984ca04"
}

response = requests.request("GET", url, headers=headers, params=querystring)

pprint(response.text)
# Out:
# ('{"Object":{"total":11159,"limit":100,"offset":0},"results":[{"title":"Spirit '
#  'of the '
#  'Ball","img":"https://occ-0-4039-1500.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABS6Ak9gRAgUwXAeBi5FipdyJc5hflpTphRIkfXslhpZ4tzpuWuZS6hU96-vk1SgV_HK8kvfsTVSUko__66hXwa65Fw.jpg?r=b0b","title_type":"movie","netflix_id":81469515,"synopsis":"One '
#  'ball. One world. One bus. A small group of activists sets off in a minibus '
#  'across 18 countries in Europe and the Middle East towards the World '
#  'Cup.","rating":"0","year":"2018","runtime":"5569","imdb_id":"tt12147532","poster":"https://m.media-amazon.com/images/M/MV5BZGM2OTFiZmItNzk5Ni00NjJjLTliZTktYjQ1N2I4ODdhMTU5XkEyXkFqcGdeQXVyNDc0ODcxNzQ@._V1_SX300.jpg","top250":0,"top250tv":0,"title_date":"2022-04-23"},{"title":"The '
#  'Curse of Robert the '
# ...

# %%
#print(response)
# Out:
# <Response [200]>

# %%
# import requests
# from pprint import pprint
# url = "https://unogs-unogs-v1.p.rapidapi.com/title/details"

# querystring = {"netflix_id":"81248118"}

# headers = {
# "X-RapidAPI-Host": "unogs-unogs-v1.p.rapidapi.com",
# "X-RapidAPI-Key": "95b5cc42f9msh0acb75461fff8eap15381ajsnfed6d984ca04"
# }

# response = requests.request("GET", url, headers=headers, params=querystring)

# pprint(response.text)
# Out:
# ('{"title":"Battle: Freestyle","maturity_label":"Coarse Language, Sexualised '
#  'Imagery","maturity_level":"","synopsis":"Amalie is elated when her and '
#  'Mikael\\u0026#39;s dance crew is selected to compete in Paris, but becomes '
#  'distracted when she reunites with her estranged '
# ...

# %% [markdown]
# ('{"title":"Battle: Freestyle","maturity_label":"Coarse Language, Sexualised '
#  'Imagery","maturity_level":"","synopsis":"Amalie is elated when her and '
#  'Mikael\\u0026#39;s dance crew is selected to compete in Paris, but becomes '
#  'distracted when she reunites with her estranged '
#  'mother.","title_type":"movie","default_image":"https://occ-0-434-2567.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfjtIfs0UCNZSs0OJP-vnzyF784dRvYJHgU7kH2ho4CfiemNGdVhb7RnKMgz5qCqOrKt8sTuZ7U684wBKl2HnM_aX7ocJ3bXRdxJzeyWg90qiSBK9TJv7qj5Ybs.jpg?r=8ac","large_image":"https://occ-0-957-2567.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABeOKcVzSVUuXaTZPJWAKePnRklHIJGz8iAMrytdRVmUPsc5B5Du9dIqAqI2U3OPt_x1UN1C1y2IZuDA2MB-_uJk_Rbkz0QWl_tnuOuqodJhcNFZ9GaUlvy8AfU4xSQ.jpg?r=8ac","netflix_id":"81248118","start_date":"2022-04-01","latest_date":"2022-04-23","year":"2022","poster":"","runtime":"","awards":"","origin_country":"","rating":"","alt_id":"tt13350858","alt_plot":"","alt_metascore":"","alt_votes":"0","alt_runtime":"5326","alt_image":""}')

# %%
# use the title call, to make a df
# column for netflix_ids, which would be use in the loop to get the details for each title

# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/search/titles"

querystring = {"order_by":"date","type":"movie","start_year":"2021"}

headers = {
	"X-RapidAPI-Host": "unogs-unogs-v1.p.rapidapi.com",
	"X-RapidAPI-Key": "95b5cc42f9msh0acb75461fff8eap15381ajsnfed6d984ca04"
}

response = requests.request("GET", url, headers=headers, params=querystring)

pprint(response.text)
# Out:
# ('{"Object":{"total":550,"limit":100,"offset":0},"results":[{"title":"Yakuza '
#  'Princess","img":"https://occ-0-2529-559.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfuFzLkfA0Tlmv9oMSRqtmKn4JgffRGxQisX9DZQKPNdRREAg21mDJZuqX1yT2wB5wZ0ct1CqStUJ1vzN-FqNUD6205qBoZPTKRxhZkJfA8i6fm5cyhJVNhz2Rs.jpg?r=4e2","title_type":"movie","netflix_id":81508834,"synopsis":"Upon '
#  'discovering she\\u0026#39;s the heiress to a prominent Yakuza crime family, '
#  'a young woman in São Paulo meets a man with amnesia — and a mysterious '
#  'artifact.","rating":"0","year":"2021","runtime":"6700","imdb_id":"tt10715446","poster":"https://m.media-amazon.com/images/M/MV5BMmFhM2YxYzMtZGU0Ny00Nzg3LTkzODUtMDZjYjVhZGEzZTJhXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg","top250":0,"top250tv":0,"title_date":"2022-04-20"},{"title":"The '
#  'Turning '
# ...

# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/search/titles"

querystring = {"offset":"101","order_by":"date","type":"movie","start_year":"2021"}

headers = {
	"X-RapidAPI-Host": "unogs-unogs-v1.p.rapidapi.com",
	"X-RapidAPI-Key": "95b5cc42f9msh0acb75461fff8eap15381ajsnfed6d984ca04"
}

response2 = requests.request("GET", url, headers=headers, params=querystring)

print(response2.text)
# Out:
# {"Object":{"total":550,"limit":100,"offset":101},"results":[{"title":"Mortal Kombat Legends: Battle of the Realms","img":"https://occ-0-1900-2567.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABXJjJgnYSzWUePOaiXJVT0-2K0KUWNQbS0XXAjJTwoQpwMEu4VhJt4VFPWT-tbwrUKIoysuqNE15uec_GrlDMKIBfA.jpg?r=195","title_type":"movie","netflix_id":81586465,"synopsis":"An invasion by the sinister lord Shao Kahn forces the heroes of Earthrealm to journey to Outworld for an epic showdown: the final Mortal Kombat.","rating":"0","year":"2021","runtime":"4786","imdb_id":"tt14901058","poster":"https://m.media-amazon.com/images/M/MV5BMDU0ZDkwMzktZDA0MC00MTc5LWE1MzEtYzg2MTU5ZWE4MTU1XkEyXkFqcGdeQXVyMTY5Nzc4MDY@._V1_SX300.jpg","top250":0,"top250tv":0,"title_date":"2022-03-01"},{"title":"The Conjuring: The Devil Made Me Do It","img":"https://occ-0-1900-2567.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABUi8sxlDFITNeaHCds628xLyXOGsnfKTpxjfN6W6fQRw8J8OF5JorQfiC58646c3xsWfQNm39vz8GwlC8ARpc-Q9LQ.jpg?r
# ...
