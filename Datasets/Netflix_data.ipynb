# %%
import opendatasets as od

# %%
dataset=('https://www.kaggle.com/datasets/akashguna/netflix-prize-shows-information')

# %%
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\netflix-prize-shows-information" (use force=True to force download)

# %%
data_dir=('.\netflix-prize-shows-information')

# %%
import pandas as pd
data_df = pd.read_csv('netflix-prize-shows-information/imdb_processed.csv')

# %%
data_df
# separate movies and tv shows, breakdown/go thru what 'kinds' of productions are available
# How many different 'kinds' of shows are available? Which kind is the most predominant?
# Which genre is the most popular? How many different genres are available to choose from? 
# The most votes per country for each title, *which country's movie/title is the most popular by vote?
# How many/which directors direct a production/s that can be translated to a language other than english? 
  # (Which directors are promoting more diversity thru the production of the thier titles?)
# Is there a correlation between how old the movie is (year released), and number of votes (popularity)? Are more recent titles more popular?
# Out:
#       Unnamed: 0                                              title    year  \
# 0              0                                    Dinosaur Planet  2003.0
# 1              1                                  Get Up and Dance!  1994.0
# 2              2                                              8 Man  1992.0
# 3              3                       What the #$*! Do We (K)now!?  2004.0
# 4              4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0
# ...          ...                                                ...     ...
# 8446        8446                                All Monsters Attack  1969.0
# 8447        8447                                       Fidel Castro  2005.0
# 8448        8448                                              Epoch  2001.0
# 8449        8449                                        The Company  2003.0
# 8450        8450                                           Predator  1987.0
#
#                 kind                                              genre  \
# 0     tv mini series             ['Documentary', 'Animation', 'Family']
# 1        video movie                                         ['Family']
# 2              movie                               ['Action', 'Sci-Fi']
# 3              movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...
# 4              movie                     ['Comedy', 'Horror', 'Sci-Fi']
# ...              ...                                                ...
# 8446           movie                 ['Adventure', 'Family', 'Fantasy']
# 8447         episode            ['Documentary', 'Biography', 'History']
# 8448        tv movie                             ['Sci-Fi', 'Thriller']
# 8449           movie                      ['Drama', 'Music', 'Romance']
# 8450           movie      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']
#
#       rating      vote                                         country  \
# 0        7.7     474.0                               ['United States']
# 1        8.1      18.0                               ['United States']
# 2        5.5      93.0                                       ['Japan']
# 3        5.3   13432.0                               ['United States']
# 4        4.5    2177.0                               ['United States']
# ...      ...       ...                                             ...
# 8446     3.9    4384.0                                       ['Japan']
# 8447     6.4      44.0                                             NaN
# 8448     4.9    2376.0                               ['United States']
# 8449     6.3    6501.0  ['United States', 'Germany', 'United Kingdom']
# 8450     7.8  386850.0                     ['United States', 'Mexico']
#
#                                language  \
# 0                           ['English']
# 1                           ['English']
# 2                          ['Japanese']
# 3      ['English', 'German', 'Spanish']
# 4                           ['English']
# ...                                 ...
# 8446                       ['Japanese']
# 8447             ['English', 'Spanish']
# 8448                        ['English']
# 8449                        ['English']
# 8450  ['English', 'Spanish', 'Russian']
#
#                                                    cast  \
# 0                 ['Christian Slater', 'Scott Sampson']
# 1     ['Paula Abdul', 'Aurorah Allain', 'Bill Bohl',...
# 2     ['Kai Shishido', 'Etsushi Takahashi', 'Sachiko...
# 3     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# ...                                                 ...
# 8446  ['Tomonori Yazaki', 'Hideyo Amamoto', 'Sachio ...
# 8447  ['Rena Baskin', 'Fulgencio Batista', 'James Bl...
# 8448  ['David Keith', 'Stephanie Niznik', "Ryan O'Ne...
# 8449  ['Neve Campbell', 'Malcolm McDowell', 'James F...
# 8450  ['Arnold Schwarzenegger', 'Carl Weathers', 'El...
#
#                                                director  \
# 0                                                   NaN
# 1                                     ['Steve Purcell']
# 2                                 ['Yasuhiro Horiuchi']
# 3     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                       ['Eric Louzil']
# ...                                                 ...
# 8446   ['Ishirô Honda', 'Jun Fukuda', 'Kengo Furusawa']
# 8447            ['Adriana Bosch', 'M Pink Christofalo']
# 8448                                      ['Matt Codd']
# 8449                                  ['Robert Altman']
# 8450                                 ['John McTiernan']
#
#                     composer  \
# 0                        NaN
# 1                        NaN
# 2            ['Carole King']
# 3     ['Christopher Franke']
# 4            ['Bob Mithoff']
# ...                      ...
# 8446      ['Kunio Miyauchi']
# 8447        ['Mason Daring']
# 8448      ['Richard McHugh']
# 8449      ['Van Dyke Parks']
# 8450      ['Alan Silvestri']
#
#                                                  writer  runtime
# 0      ['Mike Carrol', 'Mike Carroll', 'Georgann Kane']     50.0
# 1                                                   NaN     83.0
# 2     ['Kazumasa Hirai', 'Jirô Kuwata', 'Junko Suzuki']      NaN
# 3     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# ...                                                 ...      ...
# 8446                             ["Shin'ichi Sekizawa"]      NaN
# 8447                                  ['Adriana Bosch']      NaN
# 8448  ['Jonathan Raymond', 'Jonathan Raymond', 'Phil...      NaN
# 8449  ['Neve Campbell', 'Barbara Turner', 'Barbara T...      NaN
# 8450                      ['Jim Thomas', 'John Thomas']      NaN
#
# [8451 rows x 14 columns]

# %%
data_df.isnull().sum()
# Out:
# Unnamed: 0       0
# title            0
# year             0
# kind             0
# genre           67
# rating         316
# vote           316
# country        299
# language       399
# cast           171
# director      1311
# composer      2729
# writer        1247
# runtime       1653
# dtype: int64

# %%
data_df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'kind', 'genre', 'rating', 'vote',
#        'country', 'language', 'cast', 'director', 'composer', 'writer',
#        'runtime'],
#       dtype='object')

# %%
data_df["year"].max()
# Out:
# 2005.0

# %%
clean_nf_df = data_df.dropna()
clean_nf_df
clean_nf_df.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# year          0
# kind          0
# genre         0
# rating        0
# vote          0
# country       0
# language      0
# cast          0
# director      0
# composer      0
# writer        0
# runtime       0
# dtype: int64

# %%
print(len(clean_nf_df))
# Out:
# 4133

# %%
clean_nf_df
# Out:
#       Unnamed: 0                                              title    year  \
# 3              3                       What the #$*! Do We (K)now!?  2004.0
# 4              4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0
# 7              7                                          7 Seconds  2005.0
# 8              8                              By Dawn's Early Light  1990.0
# 9              9                                    Seeta Aur Geeta  1972.0
# ...          ...                                                ...     ...
# 7260        7260                                  À Nous la Liberté  1931.0
# 7261        7261                                              Shade  2003.0
# 7262        7262                                Nothing But Trouble  1991.0
# 7263        7263                                 The Whistle Blower  1986.0
# 7266        7266                                          SpaceCamp  1986.0
#
#              kind                                              genre  rating  \
# 3           movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4           movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
# 7     video movie          ['Action', 'Comedy', 'Crime', 'Thriller']     4.8
# 8        tv movie                    ['Action', 'Drama', 'Thriller']     7.1
# 9           movie  ['Adventure', 'Comedy', 'Drama', 'Family', 'Mu...     6.8
# ...           ...                                                ...     ...
# 7260        movie                              ['Comedy', 'Musical']     7.5
# 7261        movie                              ['Crime', 'Thriller']     6.3
# 7262        movie                                         ['Comedy']     5.1
# 7263        movie                                       ['Thriller']     6.2
# 7266        movie                  ['Adventure', 'Family', 'Sci-Fi']     5.7
#
#          vote                                            country  \
# 3     13432.0                                  ['United States']
# 4      2177.0                                  ['United States']
# 7      7153.0  ['United Kingdom', 'Romania', 'Switzerland', '...
# 8      2898.0                                  ['United States']
# 9      1818.0                                          ['India']
# ...       ...                                                ...
# 7260   4333.0                                         ['France']
# 7261  12485.0                                  ['United States']
# 7262  23598.0                                  ['United States']
# 7263   2069.0                                 ['United Kingdom']
# 7266  14679.0                                  ['United States']
#
#                               language  \
# 3     ['English', 'German', 'Spanish']
# 4                          ['English']
# 7                          ['English']
# 8               ['English', 'Russian']
# 9                            ['Hindi']
# ...                                ...
# 7260                        ['French']
# 7261                       ['English']
# 7262                       ['English']
# 7263            ['English', 'Russian']
# 7266                       ['English']
#
#                                                    cast  \
# 3     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# 7     ['Wesley Snipes', 'Tamzin Outhwaite', 'Deobia ...
# 8     ['Powers Boothe', 'Rebecca De Mornay', 'James ...
# 9     ['Dharmendra', 'Sanjeev Kumar', 'Hema Malini',...
# ...                                                 ...
# 7260  ['Henri Marchand', 'Raymond Cordy', 'Rolla Fra...
# 7261  ['Joe Nicolo', 'Carl Mazzocone Sr.', 'George T...
# 7262  ['Chevy Chase', 'Dan Aykroyd', 'John Candy', '...
# 7263  ['Michael Caine', 'James Fox', 'Nigel Havers',...
# 7266  ['Kate Capshaw', 'Lea Thompson', 'Kelly Presto...
#
#                                                director  \
# 3     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                       ['Eric Louzil']
# 7                                     ['Simon Fellows']
# 8                                      ['Jack Sholder']
# 9                                      ['Ramesh Sippy']
# ...                                                 ...
# 7260                                     ['René Clair']
# 7261                                  ['Damian Nieman']
# 7262                                    ['Dan Aykroyd']
# 7263                                  ['Simon Langton']
# 7266                                    ['Harry Winer']
#
#                             composer  \
# 3             ['Christopher Franke']
# 4                    ['Bob Mithoff']
# 7     ['Barry Taylor', 'Neal Acree']
# 8                   ['Trevor Jones']
# 9               ['Rahul Dev Burman']
# ...                              ...
# 7260               ['Georges Auric']
# 7261               ['James Johnzen']
# 7262               ['Michael Kamen']
# 7263                  ['John Scott']
# 7266               ['John Williams']
#
#                                                  writer  runtime
# 3     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# 7                                    ['Martin Wheeler']    118.0
# 8                 ['William Prochnau', 'Bruce Gilbert']     58.0
# 9     ['Javed Akhtar', 'Javed Akhtar', 'Satish Bhatn...     15.0
# ...                                                 ...      ...
# 7260                                     ['René Clair']    100.0
# 7261                                  ['Damian Nieman']    106.0
# 7262                   ['Peter Aykroyd', 'Dan Aykroyd']     92.0
# 7263                       ['Julian Bond', 'John Hale']    123.0
# 7266  ['Clifford Green', 'Casey T. Mitchell', 'Patri...    107.0
#
# [4133 rows x 14 columns]

# %%
clean_nf_df["kind"].unique()
# Out:
# array(['movie', 'video movie', 'tv movie', 'episode', 'tv short',
#        'video game'], dtype=object)

# %%
episode = clean_nf_df.loc[clean_nf_df["kind"] == "episode"]
episode
# Out:
#       Unnamed: 0                                title    year     kind  \
# 95            95                       Blood Will Out  1999.0  episode
# 106          106                     Strangler's Wood  1999.0  episode
# 225          225             A Morbid Taste for Bones  1996.0  episode
# 348          348               Cry of the Cat: Part 2  1998.0  episode
# 374          374                       Sharpe's Enemy  1994.0  episode
# ...          ...                                  ...     ...      ...
# 6828        6828            School's Out! The Musical  2005.0  episode
# 6842        6842                    Caught on a Train  1980.0  episode
# 6914        6914                  Murder on the Links  1996.0  episode
# 7194        7194  The Greatest Collection of Them All  1973.0  episode
# 7198        7198                  Death in the Clouds  1992.0  episode
#
#                                                   genre  rating    vote  \
# 95                        ['Crime', 'Drama', 'Mystery']     7.4   794.0
# 106                       ['Crime', 'Drama', 'Mystery']     7.9   899.0
# 225            ['Crime', 'Drama', 'History', 'Mystery']     8.1   190.0
# 348   ['Family', 'Fantasy', 'Horror', 'Mystery', 'Th...     5.5   529.0
# 374   ['Action', 'Adventure', 'Drama', 'History', 'W...     7.9  2648.0
# ...                                                 ...     ...     ...
# 6828  ['Animation', 'Adventure', 'Comedy', 'Family',...     7.4   362.0
# 6842                                          ['Drama']     7.8   355.0
# 6914          ['Crime', 'Drama', 'Mystery', 'Thriller']     7.9  1615.0
# 7194                      ['Crime', 'Drama', 'Mystery']     7.9   112.0
# 7198          ['Crime', 'Drama', 'Mystery', 'Thriller']     7.8  1560.0
#
#                                   country     language  \
# 95                     ['United Kingdom']  ['English']
# 106                    ['United Kingdom']  ['English']
# 225                    ['United Kingdom']  ['English']
# 348                            ['Canada']  ['English']
# 374                    ['United Kingdom']  ['English']
# ...                                   ...          ...
# 6828                    ['United States']  ['English']
# 6842  ['United Kingdom', 'United States']  ['English']
# 6914                   ['United Kingdom']  ['English']
# 7194                    ['United States']  ['English']
# 7198                   ['United Kingdom']  ['English']
#
#                                                    cast  \
# 95    ['John Nettles', 'Daniel Casey', 'Jane Wymark'...
# 106   ['John Nettles', 'Daniel Casey', 'Jane Wymark'...
# 225   ['Derek Jacobi', 'Michael Culver', 'Julian Fir...
# 348   ['Hamille Rustia', 'Corey Sevier', 'Arthur Eng...
# 374   ['Sean Bean', "Daragh O'Malley", 'Hugh Fraser'...
# ...                                                 ...
# 6828  ['Tara Strong', 'Daran Norris', 'Susanne Blake...
# 6842  ['Peggy Ashcroft', 'Michael Kitchen', 'Wendy R...
# 6914  ['David Suchet', 'Hugh Fraser', 'Diane Fletche...
# 7194  ['George Peppard', 'Penny Fuller', 'Mike Farre...
# 7198  ['David Suchet', 'Philip Jackson', 'Sarah Wood...
#
#                                            director  \
# 95                              ['Moira Armstrong']
# 106                           ['Jeremy Silberston']
# 225                              ['Richard Stroud']
# 348                                  ['Ron Oliver']
# 374                                   ['Tom Clegg']
# ...                                             ...
# 6828  ['Butch Hartman', 'Ken Bruce', 'Gary Conrad']
# 6842                              ['Peter Duffell']
# 6914                              ['Andrew Grieve']
# 7194                             ['George McCowan']
# 7198                          ['Stephen Whittaker']
#
#                                            composer  \
# 95                                   ['Jim Parker']
# 106                                  ['Jim Parker']
# 225                                 ['Colin Towns']
# 348                              ['Brad MacDonald']
# 374              ['Dominic Muldowney', 'John Tams']
# ...                                             ...
# 6828  ['Butch Hartman', 'Steve Marmel', 'Guy Moon']
# 6842                             ['Mike Westbrook']
# 6914                        ['Christopher Gunning']
# 7194             ['Jack Elliott', 'Allyn Ferguson']
# 7198                        ['Christopher Gunning']
#
#                                                  writer  runtime
# 95             ['Douglas Watkinson', 'Caroline Graham']    118.0
# 106             ['Anthony Horowitz', 'Caroline Graham']     93.0
# 225           ['Christopher Russell', 'Edith Pargeter']     90.0
# 348           ['Ron Oliver', 'Jeff Ross', 'R.L. Stine']     90.0
# 374               ['Eoghan Harris', 'Bernard Cornwell']     94.0
# ...                                                 ...      ...
# 6828  ['Butch Hartman', 'Steve Marmel', 'Butch Hartm...     86.0
# 6842                              ['Stephen Poliakoff']     52.0
# 6914            ['Agatha Christie', 'Anthony Horowitz']     49.0
# 7194          ['Anthony Wilson', 'Theodore J. Flicker']     58.0
# 7198              ['William Humble', 'Agatha Christie']     93.0
#
# [127 rows x 14 columns]

# %%
tv_movie = clean_nf_df.loc[clean_nf_df["kind"] == "tv movie"]
tv_movie
# Out:
#       Unnamed: 0                       title    year      kind  \
# 8              8       By Dawn's Early Light  1990.0  tv movie
# 10            10           Strange Relations  2001.0  tv movie
# 12            12                     Boycott  2001.0  tv movie
# 42            42    Inside the Space Station  2000.0  tv movie
# 81            81             Chasing Freedom  2004.0  tv movie
# ...          ...                         ...     ...       ...
# 7217        7217  Baywatch: Hawaiian Wedding  2003.0  tv movie
# 7220        7220            The Waiting Time  1999.0  tv movie
# 7223        7223           Big Bird in Japan  1988.0  tv movie
# 7224        7224                Book of Days  2003.0  tv movie
# 7258        7258               Frozen Impact  2003.0  tv movie
#
#                                  genre  rating    vote  \
# 8      ['Action', 'Drama', 'Thriller']     7.1  2898.0
# 10                 ['Drama', 'Comedy']     7.6   768.0
# 12                ['Drama', 'History']     7.2   901.0
# 42                     ['Documentary']     6.6    76.0
# 81                           ['Drama']     6.5   398.0
# ...                                ...     ...     ...
# 7217  ['Action', 'Adventure', 'Drama']     4.1  2141.0
# 7220             ['Crime', 'Thriller']     6.4    82.0
# 7223                        ['Family']     7.2   202.0
# 7224                         ['Drama']     5.0   277.0
# 7258  ['Drama', 'Romance', 'Thriller']     3.8   462.0
#
#                                   country                language  \
# 8                       ['United States']  ['English', 'Russian']
# 10    ['United Kingdom', 'United States']             ['English']
# 12                      ['United States']             ['English']
# 42                      ['United States']             ['English']
# 81            ['Canada', 'United States']             ['English']
# ...                                   ...                     ...
# 7217                    ['United States']             ['English']
# 7220                   ['United Kingdom']             ['English']
# 7223           ['Japan', 'United States']             ['English']
# 7224                    ['United States']             ['English']
# 7258                    ['United States']             ['English']
#
#                                                    cast  \
# 8     ['Powers Boothe', 'Rebecca De Mornay', 'James ...
# 10    ['Paul Reiser', 'Amber Sealey', 'Lachele Carl'...
# 12    ['Jeffrey Wright', 'Terrence Howard', 'CCH Pou...
# 42                                      ['Liam Neeson']
# 81    ['Juliette Lewis', 'Layla Alizada', 'Bruce Gra...
# ...                                                 ...
# 7217  ['David Hasselhoff', 'Pamela Anderson', 'Micha...
# 7220  ['John Thaw', 'Zara Turner', 'Mark Pegg', 'Str...
# 7223  ['Caroll Spinney', 'Brian Meehl', 'Maiko Kawak...
# 7224  ['Wil Wheaton', 'Maureen Flannigan', 'Deborah ...
# 7258  ['Ted McGinley', 'Linda Purl', 'Stacy Keach', ...
#
#                      director                                   composer  \
# 8            ['Jack Sholder']                           ['Trevor Jones']
# 10              ['Paul Seed']                ['Rupert Gregson-Williams']
# 12          ['Clark Johnson']                       ['Joseph Vitarelli']
# 42    ['Pierre de Lespinois']                         ['Michael Whalen']
# 81          ['Don McBrearty']                     ['Jonathan Goldsmith']
# ...                       ...                                        ...
# 7217     ['Douglas Schwartz']           ["John D'Andrea", 'Cory Lerios']
# 7220          ['Stuart Orme']                            ['Colin Towns']
# 7223            ['Jon Stone']  ['Tony Geiss', 'Carol Hall', 'Dick Lieb']
# 7224        ['Harry Ambrose']                           ['John Batdorf']
# 7258        ['Neil Kinsella']                          ['James T. Sale']
#
#                                                  writer  runtime
# 8                 ['William Prochnau', 'Bruce Gilbert']     58.0
# 10                                   ['Tim Kazurinsky']     75.0
# 12    ['Stewart Burns', 'Herman Daniel Farrell', 'Ti...     87.0
# 42                             ['Stephen Jay Schwartz']    150.0
# 81                                  ['Barbara Samuels']     84.0
# ...                                                 ...      ...
# 7217  ['Michael Berk', 'Douglas Schwartz', 'Gregory ...    102.0
# 7220            ['Patrick Harbinson', 'Gerald Seymour']     92.0
# 7223                                      ['Jon Stone']    107.0
# 7224                                   ['Susan Rohrer']     91.0
# 7258                                    ['Scott Brown']     88.0
#
# [497 rows x 14 columns]

# %%
total_type = clean_nf_df.groupby(["kind"]).count()["title"]
total_type
# Out:
# kind
# episode         127
# movie          3128
# tv movie        497
# tv short          2
# video game        2
# video movie     377
# Name: title, dtype: int64

# %%
video_movie = clean_nf_df.loc[clean_nf_df["kind"] == "video movie"]
video_movie
# Out:
#       Unnamed: 0                            title    year         kind  \
# 7              7                        7 Seconds  2005.0  video movie
# 15            15  FernGully 2: The Magical Rescue  1998.0  video movie
# 24            24                   The Bonesetter  2003.0  video movie
# 48            48   Bruce Lee: A Warrior's Journey  2000.0  video movie
# 58            58                         DarkWolf  2003.0  video movie
# ...          ...                              ...     ...          ...
# 7093        7093                 Lust for Dracula  2004.0  video movie
# 7108        7108    Mystic Iran: The Unseen World  2002.0  video movie
# 7181        7181               The PhanDom Menace  2002.0  video movie
# 7206        7206                   Active Stealth  1999.0  video movie
# 7238        7238   Kim Possible: The Secret Files  2003.0  video movie
#
#                                                   genre  rating    vote  \
# 7             ['Action', 'Comedy', 'Crime', 'Thriller']     4.8  7153.0
# 15      ['Animation', 'Adventure', 'Family', 'Fantasy']     4.6  1484.0
# 24                               ['Horror', 'Thriller']     1.6   210.0
# 48               ['Documentary', 'Action', 'Biography']     8.0  3007.0
# 58                                           ['Horror']     2.7  1662.0
# ...                                                 ...     ...     ...
# 7093                                         ['Horror']     3.4   335.0
# 7108                                    ['Documentary']     6.4    59.0
# 7181                                    ['Documentary']     7.7    29.0
# 7206            ['Adventure', 'Action', 'Crime', 'War']     3.3   532.0
# 7238  ['Animation', 'Family', 'Action', 'Comedy', 'M...     7.4   888.0
#
#                                                 country  \
# 7     ['United Kingdom', 'Romania', 'Switzerland', '...
# 15                                    ['United States']
# 24                                           ['Canada']
# 48     ['United States', 'United Kingdom', 'Hong Kong']
# 58                                    ['United States']
# ...                                                 ...
# 7093                                  ['United States']
# 7108                                           ['Iran']
# 7181                                      ['Australia']
# 7206                                  ['United States']
# 7238                                  ['United States']
#
#                       language  \
# 7                  ['English']
# 15                 ['English']
# 24                 ['English']
# 48    ['English', 'Cantonese']
# 58                 ['English']
# ...                        ...
# 7093               ['English']
# 7108               ['English']
# 7181               ['English']
# 7206               ['English']
# 7238               ['English']
#
#                                                    cast  \
# 7     ['Wesley Snipes', 'Tamzin Outhwaite', 'Deobia ...
# 15    ['James S. Baker', 'Matt K. Miller', 'Erik Ber...
# 24    ['Brett Kelly', 'Sherry Thurig', 'Anne-Marie F...
# 48    ['Bruce Lee', 'Kareem Abdul-Jabbar', 'Peter Ar...
# 58    ['Samaire Armstrong', 'Ryan Alosio', 'Andrea B...
# ...                                                 ...
# 7093  ['Darian Caine', 'Erin Brown', 'Julian Wells',...
# 7108           ['Shohreh Aghdashloo', 'Aryana Farshad']
# 7181  ['Don Bies', 'Chris Brennan', 'Karen Fletcher'...
# 7206  ['Daniel Baldwin', 'Hannes Jaenicke', 'Lisa Vi...
# 7238  ['Christy Carlson Romano', 'Will Friedle', 'Na...
#
#                                  director  \
# 7                       ['Simon Fellows']
# 15    ['Phil Robinson', 'David Marshall']
# 24                        ['Brett Kelly']
# 48           ['John Little', 'Bruce Lee']
# 58                   ['Richard Friedman']
# ...                                   ...
# 7093                   ['Tony Marsiglia']
# 7108                   ['Aryana Farshad']
# 7181  ['Warwick Holt', 'Craig E. Tonkin']
# 7206                    ['Fred Olen Ray']
# 7238      ['Chris Bailey', 'Steve Loter']
#
#                                                composer  \
# 7                        ['Barry Taylor', 'Neal Acree']
# 15                                ['Nerida Tyson-Chew']
# 24                                  ['Sylvain Lavigne']
# 48                                    ['Wayne Hawkins']
# 58                                      ['Geoff Levin']
# ...                                                 ...
# 7093                                       ['Don Mike']
# 7108                                  ['Ahmad Pezhman']
# 7181  ['James Evans', 'Martin Evans', 'Brett Harring...
# 7206                      ['David Wurst', 'Eric Wurst']
# 7238                                     ['Adam Berry']
#
#                                                  writer  runtime
# 7                                    ['Martin Wheeler']    118.0
# 15     ['Richard Tulloch', 'Diana Young', 'Chris Fink']    117.0
# 24                                      ['Brett Kelly']     82.0
# 48            ['Bruce Lee', 'John Little', 'Bey Logan']     98.0
# 58    ['Geoffrey Alan Holliday', 'Chuck Scholl', 'Ge...    101.0
# ...                                                 ...      ...
# 7093                                 ['Tony Marsiglia']     99.0
# 7108             ['Janelle Balnicke', 'Aryana Farshad']     89.0
# 7181                ['Warwick Holt', 'Craig E. Tonkin']     80.0
# 7206                                  ['Steve Latshaw']     94.0
# 7238  ['Mark McCorkle', 'Madellaine Paxson', 'Bob Sc...     93.0
#
# [377 rows x 14 columns]

# %%
# values = ["episode", "video games", "tv short"]
# test = (clean_nf_df[clean_nf_df.kind!="episode"])
# test2 = (clean_nf_df[clean_nf_df.kind!="video games"])
# test3 = (clean_nf_df[clean_nf_df.kind!="tv short"])
indexNames = clean_nf_df[(clean_nf_df["kind"] == "episode") | (clean_nf_df["kind"] == "tv short") |(clean_nf_df["kind"] == "video game")].index
clean_nf_df.drop(indexNames , inplace=True)
# Out:
# C:\Users\stefa\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# test
# test_unique = test["kind"].unique()
# test_unique
clean_nf_df["kind"].unique()
# Out:
# array(['movie', 'video movie', 'tv movie'], dtype=object)

# %%
clean_nf_df
# Out:
#       Unnamed: 0                                              title    year  \
# 3              3                       What the #$*! Do We (K)now!?  2004.0
# 4              4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0
# 7              7                                          7 Seconds  2005.0
# 8              8                              By Dawn's Early Light  1990.0
# 9              9                                    Seeta Aur Geeta  1972.0
# ...          ...                                                ...     ...
# 7260        7260                                  À Nous la Liberté  1931.0
# 7261        7261                                              Shade  2003.0
# 7262        7262                                Nothing But Trouble  1991.0
# 7263        7263                                 The Whistle Blower  1986.0
# 7266        7266                                          SpaceCamp  1986.0
#
#              kind                                              genre  rating  \
# 3           movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3
# 4           movie                     ['Comedy', 'Horror', 'Sci-Fi']     4.5
# 7     video movie          ['Action', 'Comedy', 'Crime', 'Thriller']     4.8
# 8        tv movie                    ['Action', 'Drama', 'Thriller']     7.1
# 9           movie  ['Adventure', 'Comedy', 'Drama', 'Family', 'Mu...     6.8
# ...           ...                                                ...     ...
# 7260        movie                              ['Comedy', 'Musical']     7.5
# 7261        movie                              ['Crime', 'Thriller']     6.3
# 7262        movie                                         ['Comedy']     5.1
# 7263        movie                                       ['Thriller']     6.2
# 7266        movie                  ['Adventure', 'Family', 'Sci-Fi']     5.7
#
#          vote                                            country  \
# 3     13432.0                                  ['United States']
# 4      2177.0                                  ['United States']
# 7      7153.0  ['United Kingdom', 'Romania', 'Switzerland', '...
# 8      2898.0                                  ['United States']
# 9      1818.0                                          ['India']
# ...       ...                                                ...
# 7260   4333.0                                         ['France']
# 7261  12485.0                                  ['United States']
# 7262  23598.0                                  ['United States']
# 7263   2069.0                                 ['United Kingdom']
# 7266  14679.0                                  ['United States']
#
#                               language  \
# 3     ['English', 'German', 'Spanish']
# 4                          ['English']
# 7                          ['English']
# 8               ['English', 'Russian']
# 9                            ['Hindi']
# ...                                ...
# 7260                        ['French']
# 7261                       ['English']
# 7262                       ['English']
# 7263            ['English', 'Russian']
# 7266                       ['English']
#
#                                                    cast  \
# 3     ['Marlee Matlin', 'Elaine Hendrix', 'John Ross...
# 4     ['Brick Bronsky', 'Lisa Gaye', 'Leesa Rowland'...
# 7     ['Wesley Snipes', 'Tamzin Outhwaite', 'Deobia ...
# 8     ['Powers Boothe', 'Rebecca De Mornay', 'James ...
# 9     ['Dharmendra', 'Sanjeev Kumar', 'Hema Malini',...
# ...                                                 ...
# 7260  ['Henri Marchand', 'Raymond Cordy', 'Rolla Fra...
# 7261  ['Joe Nicolo', 'Carl Mazzocone Sr.', 'George T...
# 7262  ['Chevy Chase', 'Dan Aykroyd', 'John Candy', '...
# 7263  ['Michael Caine', 'James Fox', 'Nigel Havers',...
# 7266  ['Kate Capshaw', 'Lea Thompson', 'Kelly Presto...
#
#                                                director  \
# 3     ['William Arntz', 'Betsy Chasse', 'Mark Vicente']
# 4                                       ['Eric Louzil']
# 7                                     ['Simon Fellows']
# 8                                      ['Jack Sholder']
# 9                                      ['Ramesh Sippy']
# ...                                                 ...
# 7260                                     ['René Clair']
# 7261                                  ['Damian Nieman']
# 7262                                    ['Dan Aykroyd']
# 7263                                  ['Simon Langton']
# 7266                                    ['Harry Winer']
#
#                             composer  \
# 3             ['Christopher Franke']
# 4                    ['Bob Mithoff']
# 7     ['Barry Taylor', 'Neal Acree']
# 8                   ['Trevor Jones']
# 9               ['Rahul Dev Burman']
# ...                              ...
# 7260               ['Georges Auric']
# 7261               ['James Johnzen']
# 7262               ['Michael Kamen']
# 7263                  ['John Scott']
# 7266               ['John Williams']
#
#                                                  writer  runtime
# 3     ['William Arntz', 'Betsy Chasse', 'Matthew Hof...     60.0
# 4        ['Lloyd Kaufman', 'Carl Morano', 'Matt Unger']     96.0
# 7                                    ['Martin Wheeler']    118.0
# 8                 ['William Prochnau', 'Bruce Gilbert']     58.0
# 9     ['Javed Akhtar', 'Javed Akhtar', 'Satish Bhatn...     15.0
# ...                                                 ...      ...
# 7260                                     ['René Clair']    100.0
# 7261                                  ['Damian Nieman']    106.0
# 7262                   ['Peter Aykroyd', 'Dan Aykroyd']     92.0
# 7263                       ['Julian Bond', 'John Hale']    123.0
# 7266  ['Clifford Green', 'Casey T. Mitchell', 'Patri...    107.0
#
# [4002 rows x 14 columns]

# %%
# d = {'col1': [0, 1, 2, 3], 'col2': pd.Series([2, 3], index=[2, 3])}
# pd.DataFrame(data=d, index=[0, 1, 2, 3])

# new_reduced_df = {'Title': []}

new_reduced_df = clean_nf_df.drop(['Unnamed: 0','vote', 'country', 'language', 'cast', 'director', 'composer', 'writer'], axis = 1)
new_reduced = new_reduced_df.reset_index(drop=True)
new_reduced
# Out:
#                                                   title    year         kind  \
# 0                          What the #$*! Do We (K)now!?  2004.0        movie
# 1     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0        movie
# 2                                             7 Seconds  2005.0  video movie
# 3                                 By Dawn's Early Light  1990.0     tv movie
# 4                                       Seeta Aur Geeta  1972.0        movie
# ...                                                 ...     ...          ...
# 3997                                  À Nous la Liberté  1931.0        movie
# 3998                                              Shade  2003.0        movie
# 3999                                Nothing But Trouble  1991.0        movie
# 4000                                 The Whistle Blower  1986.0        movie
# 4001                                          SpaceCamp  1986.0        movie
#
#                                                   genre  rating  runtime
# 0     ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3     60.0
# 1                        ['Comedy', 'Horror', 'Sci-Fi']     4.5     96.0
# 2             ['Action', 'Comedy', 'Crime', 'Thriller']     4.8    118.0
# 3                       ['Action', 'Drama', 'Thriller']     7.1     58.0
# 4     ['Adventure', 'Comedy', 'Drama', 'Family', 'Mu...     6.8     15.0
# ...                                                 ...     ...      ...
# 3997                              ['Comedy', 'Musical']     7.5    100.0
# 3998                              ['Crime', 'Thriller']     6.3    106.0
# 3999                                         ['Comedy']     5.1     92.0
# 4000                                       ['Thriller']     6.2    123.0
# 4001                  ['Adventure', 'Family', 'Sci-Fi']     5.7    107.0
#
# [4002 rows x 6 columns]

# %%
new_reduced["year"] = new_reduced["year"].astype("int")
new_reduced["runtime"] = new_reduced["runtime"].astype("int")
new_reduced
# Out:
#                                                   title  year         kind  \
# 0                          What the #$*! Do We (K)now!?  2004        movie
# 1     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991        movie
# 2                                             7 Seconds  2005  video movie
# 3                                 By Dawn's Early Light  1990     tv movie
# 4                                       Seeta Aur Geeta  1972        movie
# ...                                                 ...   ...          ...
# 3997                                  À Nous la Liberté  1931        movie
# 3998                                              Shade  2003        movie
# 3999                                Nothing But Trouble  1991        movie
# 4000                                 The Whistle Blower  1986        movie
# 4001                                          SpaceCamp  1986        movie
#
#                                                   genre  rating  runtime
# 0     ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...     5.3       60
# 1                        ['Comedy', 'Horror', 'Sci-Fi']     4.5       96
# 2             ['Action', 'Comedy', 'Crime', 'Thriller']     4.8      118
# 3                       ['Action', 'Drama', 'Thriller']     7.1       58
# 4     ['Adventure', 'Comedy', 'Drama', 'Family', 'Mu...     6.8       15
# ...                                                 ...     ...      ...
# 3997                              ['Comedy', 'Musical']     7.5      100
# 3998                              ['Crime', 'Thriller']     6.3      106
# 3999                                         ['Comedy']     5.1       92
# 4000                                       ['Thriller']     6.2      123
# 4001                  ['Adventure', 'Family', 'Sci-Fi']     5.7      107
#
# [4002 rows x 6 columns]

# %%
new_reduced.to_csv("netflix_2005.csv", mode="w")
